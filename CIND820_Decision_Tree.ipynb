# %% [markdown]
# <a href="https://colab.research.google.com/github/prashanthvijayaraja-tmu/CIND-820/blob/main/CIND820_Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('labelencoded_df.csv')

# %%
data
# Out:
#         Unnamed: 0.1  Unnamed: 0  posted_speed_limit  device_condition  \
# 0                  0           0                  30                 1
# 1                  1           1                  50                 3
# 2                  2           2                  30                 1
# 3                  3           3                  30                 3
# 4                  4           4                  15                 1
# ...              ...         ...                 ...               ...
# 769976        769976      794951                  30                 3
# 769977        769977      794952                  30                 3
# 769978        769978      794953                  30                 3
# 769979        769979      794954                  30                 3
# 769980        769980      794955                  30                 3
#
#         weather_condition  lighting_condition  first_crash_type  \
# 0                       2                   4                 0
# 1                       2                   1                10
# 2                       2                   3                 7
# 3                       2                   1                15
# 4                       2                   3                10
# ...                   ...                 ...               ...
# 769976                  2                   3                 7
# 769977                 11                   5                15
# 769978                  2                   3                 7
# 769979                  2                   1                17
# 769980                  2                   1                 0
#
#         trafficway_type  alignment  roadway_surface_cond  road_defect  \
# 0                     5          3                     0            1
# 1                     3          3                     0            1
# 2                     2          3                     0            1
# 3                     8          3                     0            1
# 4                    11          3                     0            1
# ...                 ...        ...                   ...          ...
# 769976               10          3                     0            1
# 769977               11          3                     5            5
# 769978               10          3                     0            1
# 769979                8          3                     0            1
# 769980                8          3                     5            5
#
#         crash_type  damage  prim_contributory_cause  sec_contributory_cause  \
# 0                0       2                       36                      26
# 1                1       2                       19                      19
# 2                1       2                       17                      28
# 3                1       2                       18                      26
# 4                0       2                       19                       8
# ...            ...     ...                      ...                     ...
# 769976           1       1                       21                      36
# 769977           1       1                       36                      26
# 769978           1       2                       21                      21
# 769979           0       2                       36                      26
# 769980           1       2                       18                      26
#
#         injuries_total  crash_hour  crash_day_of_week  crash_month  severity
# 0                  3.0          19                  3            9       9.0
# 1                  0.0          18                  6            9       2.0
# 2                  0.0          14                  7            7       1.0
# 3                  0.0          23                  4            8       2.0
# 4                  1.0          12                  6            8       3.0
# ...                ...         ...                ...          ...       ...
# 769976             0.0           7                  2           11       1.0
# 769977             0.0          18                  3           10       2.0
# 769978             0.0          23                  7           11       1.0
# 769979             0.0          18                  2           11       4.0
# 769980             0.0          19                  2           11       2.0
#
# [769981 rows x 20 columns]

# %%
data = data.drop(columns=['Unnamed: 0','Unnamed: 0.1'])

# %%
data
# Out:
#         posted_speed_limit  device_condition  weather_condition  \
# 0                       30                 1                  2
# 1                       50                 3                  2
# 2                       30                 1                  2
# 3                       30                 3                  2
# 4                       15                 1                  2
# ...                    ...               ...                ...
# 769976                  30                 3                  2
# 769977                  30                 3                 11
# 769978                  30                 3                  2
# 769979                  30                 3                  2
# 769980                  30                 3                  2
#
#         lighting_condition  first_crash_type  trafficway_type  alignment  \
# 0                        4                 0                5          3
# 1                        1                10                3          3
# 2                        3                 7                2          3
# 3                        1                15                8          3
# 4                        3                10               11          3
# ...                    ...               ...              ...        ...
# 769976                   3                 7               10          3
# 769977                   5                15               11          3
# 769978                   3                 7               10          3
# 769979                   1                17                8          3
# 769980                   1                 0                8          3
#
#         roadway_surface_cond  road_defect  crash_type  damage  \
# 0                          0            1           0       2
# 1                          0            1           1       2
# 2                          0            1           1       2
# 3                          0            1           1       2
# 4                          0            1           0       2
# ...                      ...          ...         ...     ...
# 769976                     0            1           1       1
# 769977                     5            5           1       1
# 769978                     0            1           1       2
# 769979                     0            1           0       2
# 769980                     5            5           1       2
#
#         prim_contributory_cause  sec_contributory_cause  injuries_total  \
# 0                            36                      26             3.0
# 1                            19                      19             0.0
# 2                            17                      28             0.0
# 3                            18                      26             0.0
# 4                            19                       8             1.0
# ...                         ...                     ...             ...
# 769976                       21                      36             0.0
# 769977                       36                      26             0.0
# 769978                       21                      21             0.0
# 769979                       36                      26             0.0
# 769980                       18                      26             0.0
#
#         crash_hour  crash_day_of_week  crash_month  severity
# 0               19                  3            9       9.0
# 1               18                  6            9       2.0
# 2               14                  7            7       1.0
# 3               23                  4            8       2.0
# 4               12                  6            8       3.0
# ...            ...                ...          ...       ...
# 769976           7                  2           11       1.0
# 769977          18                  3           10       2.0
# 769978          23                  7           11       1.0
# 769979          18                  2           11       4.0
# 769980          19                  2           11       2.0
#
# [769981 rows x 18 columns]

# %%
y = data['severity']
X = data.drop('severity', axis=1)


sc = RobustScaler()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

X_train  = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
Tree = DecisionTreeClassifier()
Tree = Tree.fit(X_train, y_train)

y_pred = Tree.predict(X_test)
print("Tree accuracy: ", accuracy_score(y_test,y_pred)*100)

print("Train Accuracy:", Tree.score(X_train, y_train))
print("Test Accuracy:", Tree.score(X_test, y_test))
# Out:
# Tree accuracy:  54.58028403150711
# Train Accuracy: 0.987170121301852
# Test Accuracy: 0.5458028403150711

# %%
giniTree = DecisionTreeClassifier(criterion = "gini", splitter = "random", random_state = 42)
giniTree = giniTree.fit(X_train, y_train)

y_pred = giniTree.predict(X_test)
print("Gini Tree accuracy: ", accuracy_score(y_test,y_pred)*100)

print("Train Accuracy:", giniTree.score(X_train, y_train))
print("Test Accuracy:", giniTree.score(X_test, y_test))
# Out:
# Gini Tree accuracy:  55.00237017604239
# Train Accuracy: 0.987170121301852
# Test Accuracy: 0.5500237017604239

# %%
entropyTree = DecisionTreeClassifier(criterion = "entropy", splitter = "random", random_state = 42)
entropyTree = entropyTree.fit(X_train, y_train)

y_pred = entropyTree.predict(X_test)
print("Entropy Tree accuracy: ", accuracy_score(y_test,y_pred)*100)
print("Train Accuracy:", entropyTree.score(X_train, y_train))
print("Test Accuracy:", entropyTree.score(X_test, y_test))
# Out:
# Entropy Tree accuracy:  55.05237115008734
# Train Accuracy: 0.987170121301852
# Test Accuracy: 0.5505237115008734

# %%
rf = RandomForestClassifier(criterion = "gini")
rf = rf.fit(X_train, y_train)

# Predict on the test set
best_test_pred = rf.predict(X_test)
print('Accuracy on training set: ', rf.score(X_train, y_train))
print('Accuracy on the test set: ', accuracy_score(y_test, best_test_pred))
print()

print("Classification Report")
print(classification_report(y_test, best_test_pred))
print()

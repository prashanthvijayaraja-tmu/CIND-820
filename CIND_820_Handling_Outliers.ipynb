# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

d=pd.read_csv('Cleandata.csv')

# %%
d
# Out:
#         Unnamed: 0  Year  Severity  Start_Lat   Start_Lng  Distance(mi)  \
# 0                0  2016         2  39.063148  -84.032608         0.010
# 1                1  2016         3  39.747753  -84.205582         0.010
# 2                2  2016         2  39.627781  -84.188354         0.010
# 3                3  2016         3  40.100590  -82.925194         0.010
# 4                4  2016         2  39.758274  -84.230507         0.000
# ...            ...   ...       ...        ...         ...           ...
# 314280      314280  2017         2  28.879630  -82.092960         0.722
# 314281      314281  2017         2  37.993881  -92.795869         0.000
# 314282      314282  2017         2  46.617235 -113.051251         0.000
# 314283      314283  2017         4  46.672100 -113.153690         9.486
# 314284      314284  2017         3  34.344290 -118.504950         0.430
#
#                            Street          City       County State  \
# 0                  State Route 32  Williamsburg     Clermont    OH
# 1                          I-75 S        Dayton   Montgomery    OH
# 2       Miamisburg Centerville Rd        Dayton   Montgomery    OH
# 3                  Westerville Rd   Westerville     Franklin    OH
# 4                  N Woodward Ave        Dayton   Montgomery    OH
# ...                           ...           ...          ...   ...
# 314280                     I-75 S      Wildwood       Sumter    FL
# 314281             Sunny Slope Dr     Camdenton       Camden    MO
# 314282                    US-12 W      Drummond      Granite    MT
# 314283                    US-12 W      Drummond      Granite    MT
# 314284                    CA-14 S       Newhall  Los Angeles    CA
#
#        Airport_Code  Temperature(F)  Wind_Chill(F)  Visibility(mi)  \
# 0              KI69            36.0           33.3            10.0
# 1              KDAY            35.1           31.0             9.0
# 2              KMGY            36.0           33.3             6.0
# 3              KCMH            37.9           35.5             7.0
# 4              KDAY            34.0           31.0             7.0
# ...             ...             ...            ...             ...
# 314280         KVVG            80.0           80.0            10.0
# 314281         KH21            75.0           75.0            10.0
# 314282         K3DU            89.0           89.0             3.0
# 314283         K3DU            57.0           57.0             4.0
# 314284         K3A6            85.0           85.0            10.0
#
#        Wind_Direction        Weather_Condition  Traffic_Signal Sunrise_Sunset  \
# 0                  SW                 Overcast            True          Night
# 1                  SW            Mostly Cloudy           False          Night
# 2                  SW            Mostly Cloudy            True            Day
# 3                 SSW               Light Rain           False            Day
# 4                 WSW                 Overcast           False            Day
# ...               ...                      ...             ...            ...
# 314280            VAR  Light Rain with Thunder           False            Day
# 314281              N                   Cloudy           False            Day
# 314282            SSE                     Haze           False            Day
# 314283           CALM                     Haze           False          Night
# 314284           CALM                     Fair           False            Day
#
#         TimeDiff
# 0           30.0
# 1           30.0
# 2           30.0
# 3           30.0
# 4           30.0
# ...          ...
# 314280     360.0
# 314281     360.0
# 314282     360.0
# 314283     360.0
# 314284     360.0
#
# [314285 rows x 19 columns]

# %%
d= d.drop(columns=['Unnamed: 0'])
d
# Out:
#         Year  Severity  Start_Lat   Start_Lng  Distance(mi)  \
# 0       2016         2  39.063148  -84.032608         0.010
# 1       2016         3  39.747753  -84.205582         0.010
# 2       2016         2  39.627781  -84.188354         0.010
# 3       2016         3  40.100590  -82.925194         0.010
# 4       2016         2  39.758274  -84.230507         0.000
# ...      ...       ...        ...         ...           ...
# 314280  2017         2  28.879630  -82.092960         0.722
# 314281  2017         2  37.993881  -92.795869         0.000
# 314282  2017         2  46.617235 -113.051251         0.000
# 314283  2017         4  46.672100 -113.153690         9.486
# 314284  2017         3  34.344290 -118.504950         0.430
#
#                            Street          City       County State  \
# 0                  State Route 32  Williamsburg     Clermont    OH
# 1                          I-75 S        Dayton   Montgomery    OH
# 2       Miamisburg Centerville Rd        Dayton   Montgomery    OH
# 3                  Westerville Rd   Westerville     Franklin    OH
# 4                  N Woodward Ave        Dayton   Montgomery    OH
# ...                           ...           ...          ...   ...
# 314280                     I-75 S      Wildwood       Sumter    FL
# 314281             Sunny Slope Dr     Camdenton       Camden    MO
# 314282                    US-12 W      Drummond      Granite    MT
# 314283                    US-12 W      Drummond      Granite    MT
# 314284                    CA-14 S       Newhall  Los Angeles    CA
#
#        Airport_Code  Temperature(F)  Wind_Chill(F)  Visibility(mi)  \
# 0              KI69            36.0           33.3            10.0
# 1              KDAY            35.1           31.0             9.0
# 2              KMGY            36.0           33.3             6.0
# 3              KCMH            37.9           35.5             7.0
# 4              KDAY            34.0           31.0             7.0
# ...             ...             ...            ...             ...
# 314280         KVVG            80.0           80.0            10.0
# 314281         KH21            75.0           75.0            10.0
# 314282         K3DU            89.0           89.0             3.0
# 314283         K3DU            57.0           57.0             4.0
# 314284         K3A6            85.0           85.0            10.0
#
#        Wind_Direction        Weather_Condition  Traffic_Signal Sunrise_Sunset  \
# 0                  SW                 Overcast            True          Night
# 1                  SW            Mostly Cloudy           False          Night
# 2                  SW            Mostly Cloudy            True            Day
# 3                 SSW               Light Rain           False            Day
# 4                 WSW                 Overcast           False            Day
# ...               ...                      ...             ...            ...
# 314280            VAR  Light Rain with Thunder           False            Day
# 314281              N                   Cloudy           False            Day
# 314282            SSE                     Haze           False            Day
# 314283           CALM                     Haze           False          Night
# 314284           CALM                     Fair           False            Day
#
#         TimeDiff
# 0           30.0
# 1           30.0
# 2           30.0
# 3           30.0
# 4           30.0
# ...          ...
# 314280     360.0
# 314281     360.0
# 314282     360.0
# 314283     360.0
# 314284     360.0
#
# [314285 rows x 18 columns]

# %%
d.dtypes
# Out:
# Year                   int64
# Severity               int64
# Start_Lat            float64
# Start_Lng            float64
# Distance(mi)         float64
# Street                object
# City                  object
# County                object
# State                 object
# Airport_Code          object
# Temperature(F)       float64
# Wind_Chill(F)        float64
# Visibility(mi)       float64
# Wind_Direction        object
# Weather_Condition     object
# Traffic_Signal          bool
# Sunrise_Sunset        object
# TimeDiff             float64
# dtype: object

# %%
plt.figure(figsize=(10,6))  # Adjust the figure size if needed
sns.boxplot(data=d[['Start_Lat']], orient='v')  # Replace with your feature names
plt.xlabel('Features')
plt.ylabel('Values')
plt.title('Box Plots for Multiple Features')
plt.xticks(rotation=45)  # Rotate x-axis labels for better visibility if needed
plt.show()

# %%
from scipy import stats
import matplotlib.pyplot as plt

# Generate a Q-Q plot
for i in d.columns:
    if(d[i].dtype=="object"):
        continue

    plt.figure()
    stats.probplot(d[i], dist="norm", plot=plt)
    plt.title('Q-Q Plot of '+i)
    plt.show()

# %%
import matplotlib.pyplot as plt

# Generate a Q-Q plot
for i in d.columns:
    if(d[i].dtype=="object"):
        continue

    plt.figure()
    sns.distplot(d[i])
    plt.show()
# Out:
# <ipython-input-10-3d8ed92e53a3>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d[i])
# <ipython-input-10-3d8ed92e53a3>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d[i])
# <ipython-input-10-3d8ed92e53a3>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d[i])
# <ipython-input-10-3d8ed92e53a3>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d[i])
# <ipython-input-10-3d8ed92e53a3>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d[i])
# <ipython-input-10-3d8ed92e53a3>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d[i])
# <ipython-input-10-3d8ed92e53a3>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d[i])
# <ipython-input-10-3d8ed92e53a3>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d[i])
# <ipython-input-10-3d8ed92e53a3>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d[i])
# <ipython-input-10-3d8ed92e53a3>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d[i])

# %%
import matplotlib.pyplot as plt

# Generate a boxplot
for i in d.columns:
    if(d[i].dtype=="object"):
        continue

    plt.figure()
    sns.boxplot(d[i])
    plt.show()

# %%
d.dtypes
# Out:
# Year                   int64
# Severity               int64
# Start_Lat            float64
# Start_Lng            float64
# Distance(mi)         float64
# Street                object
# City                  object
# County                object
# State                 object
# Airport_Code          object
# Temperature(F)       float64
# Wind_Chill(F)        float64
# Visibility(mi)       float64
# Wind_Direction        object
# Weather_Condition     object
# Traffic_Signal          bool
# Sunrise_Sunset        object
# TimeDiff             float64
# dtype: object

# %%
import pandas as pd

# Load your dataset as a DataFrame
# Replace 'your_dataset.csv' with the actual path to your dataset file

# Define a threshold for outliers (e.g., 1.5 times IQR)
threshold = 1.5

# Initialize an empty DataFrame to store data without outliers
data_no_outliers = pd.DataFrame()

# Iterate through each column (feature) in the dataset
for column in d.columns:
    if(d[column].dtype=="object" or d[column].dtype=="bool"):
        continue
    # Calculate Q1 and Q3 for the current column
    Q1 = d[column].quantile(0.25)
    Q3 = d[column].quantile(0.75)

    # Calculate IQR for the current column
    IQR = Q3 - Q1

    # Define the lower and upper bounds for outliers
    lower_bound = Q1 - threshold * IQR
    upper_bound = Q3 + threshold * IQR

    # Filter rows that are not outliers for the current column
    filtered_data = d[(d[column] >= lower_bound) & (d[column] <= upper_bound)]

    # Append the filtered data to the result DataFrame
    data_no_outliers[column] = filtered_data[column]
    # data_no_outliers = pd.concat([data_no_outliers, filtered_data])

# Reset the index of the result DataFrame
data_no_outliers.reset_index(drop=True, inplace=True)
data_no_outliers['Temperature(F)']
print("maxi1:",max(data_no_outliers['Temperature(F)']))
print("maxi2:",max(d['Temperature(F)']))
# data_no_outliers now contains the dataset with outliers removed column-wise
# Out:
# maxi1: 63.0
# maxi2: 111.0

# %%
# Plot after removing outliers
import matplotlib.pyplot as plt

for i in data_no_outliers.columns:
    if(data_no_outliers[i].dtype=="object"):
        continue

    plt.figure()
    sns.distplot(data_no_outliers[i])
    plt.show()
# Out:
# <ipython-input-14-98364dbaee9e>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_outliers[i])
# <ipython-input-14-98364dbaee9e>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_outliers[i])
# <ipython-input-14-98364dbaee9e>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_outliers[i])
# <ipython-input-14-98364dbaee9e>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_outliers[i])
# <ipython-input-14-98364dbaee9e>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_outliers[i])
# <ipython-input-14-98364dbaee9e>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_outliers[i])
# <ipython-input-14-98364dbaee9e>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_outliers[i])
# <ipython-input-14-98364dbaee9e>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_outliers[i])
# <ipython-input-14-98364dbaee9e>:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data_no_outliers[i])

# %%
data_no_outliers.to_csv("WithoutOutliers.csv")

# %%
newd=pd.read_csv('WithoutOutliers.csv')

# %%
newd
# Out:
#         Unnamed: 0  Year  Severity  Start_Lat   Start_Lng  Distance(mi)  \
# 0                0  2016         2  39.063148  -84.032608          0.01
# 1                1  2016         3  39.747753  -84.205582          0.01
# 2                2  2016         2  39.627781  -84.188354          0.01
# 3                3  2016         3  40.100590  -82.925194          0.01
# 4                4  2016         2  39.758274  -84.230507          0.00
# ...            ...   ...       ...        ...         ...           ...
# 314280      314280  2017         2        NaN  -82.092960           NaN
# 314281      314281  2017         2  37.993881  -92.795869          0.00
# 314282      314282  2017         2  46.617235 -113.051251          0.00
# 314283      314283  2017         4  46.672100 -113.153690           NaN
# 314284      314284  2017         3  34.344290 -118.504950           NaN
#
#         Temperature(F)  Wind_Chill(F)  Visibility(mi)  TimeDiff
# 0                 36.0           33.3            10.0      30.0
# 1                 35.1           31.0             9.0      30.0
# 2                 36.0           33.3             NaN      30.0
# 3                 37.9           35.5             NaN      30.0
# 4                 34.0           31.0             NaN      30.0
# ...                ...            ...             ...       ...
# 314280             NaN            NaN            10.0       NaN
# 314281             NaN            NaN            10.0       NaN
# 314282             NaN            NaN             NaN       NaN
# 314283            57.0           57.0             NaN       NaN
# 314284             NaN            NaN            10.0       NaN
#
# [314285 rows x 10 columns]
